# %% [markdown]
# # Financial Growth Analysis

# %% [markdown]
# ## Importing Libraries
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
# import seaborn as sns
# import plotly.express as px
# import plotly.graph_objects as go

# %%
## Load Dataset  
data = pd.read_csv('final_report.csv')

# %%
data
# Out:
#     Year  Total Revenue  Net Income  Total Assets  Total Liabilities  \
# 0   2024         245122       88136        512163             243686
# 1   2023         211915       72361        411976             205753
# 2   2022         198270       72738        364840             198298
# 3   2021         168088       61271        333779             191791
# 4   2024          97690        7091        106618              43009
# 5   2023          96773       14974        106618              43009
# 6   2022          81462       12556         82338              36440
# 7   2021          53821        5519         62131              30548
# 8   2024         391035       93736        364980             308030
# 9   2023         383285       96995        352583             290437
# 10  2022         394328       99803        352755             302083
# 11  2021         365817       94680        351002             287912
#
#     Cash Flow from Operating Activities    Company
# 0                                118548  Microsoft
# 1                                 87582  Microsoft
# 2                                 89035  Microsoft
# 3                                 76740  Microsoft
# 4                                 14923      Tesla
# 5                                 13256      Tesla
# 6                                 14724      Tesla
# 7                                 11497      Tesla
# 8                                118500      Apple
# 9                                110543      Apple
# 10                               122151      Apple
# 11                               104038      Apple

# %% [markdown]
# ## Calculating Growth Metrics

# %%
data['Revenue Growth (%)'] = data.groupby('Company')['Total Revenue'].pct_change() * 100
data['Net Income Growth (%)'] = data.groupby('Company')['Net Income'].pct_change() * 100

# %%
data
# Out:
#     Year  Total Revenue  Net Income  Total Assets  Total Liabilities  \
# 0   2024         245122       88136        512163             243686
# 1   2023         211915       72361        411976             205753
# 2   2022         198270       72738        364840             198298
# 3   2021         168088       61271        333779             191791
# 4   2024          97690        7091        106618              43009
# 5   2023          96773       14974        106618              43009
# 6   2022          81462       12556         82338              36440
# 7   2021          53821        5519         62131              30548
# 8   2024         391035       93736        364980             308030
# 9   2023         383285       96995        352583             290437
# 10  2022         394328       99803        352755             302083
# 11  2021         365817       94680        351002             287912
#
#     Cash Flow from Operating Activities    Company  Revenue Growth (%)  \
# 0                                118548  Microsoft                 NaN
# 1                                 87582  Microsoft          -13.547132
# 2                                 89035  Microsoft           -6.438902
# 3                                 76740  Microsoft          -15.222676
# 4                                 14923      Tesla                 NaN
# 5                                 13256      Tesla           -0.938684
# 6                                 14724      Tesla          -15.821562
# 7                                 11497      Tesla          -33.931158
# 8                                118500      Apple                 NaN
# 9                                110543      Apple           -1.981920
# 10                               122151      Apple            2.881146
# 11                               104038      Apple           -7.230275
#
#     Net Income Growth (%)
# 0                     NaN
# 1              -17.898475
# 2                0.520999
# 3              -15.764800
# 4                     NaN
# 5              111.169088
# 6              -16.147990
# 7              -56.044919
# 8                     NaN
# 9                3.476786
# 10               2.894995
# 11              -5.133112

# %% [markdown]
# ## Handling Missing Values

# %%
data.fillna(0, inplace=True)

# %%
data
# Out:
#     Year  Total Revenue  Net Income  Total Assets  Total Liabilities  \
# 0   2024         245122       88136        512163             243686
# 1   2023         211915       72361        411976             205753
# 2   2022         198270       72738        364840             198298
# 3   2021         168088       61271        333779             191791
# 4   2024          97690        7091        106618              43009
# 5   2023          96773       14974        106618              43009
# 6   2022          81462       12556         82338              36440
# 7   2021          53821        5519         62131              30548
# 8   2024         391035       93736        364980             308030
# 9   2023         383285       96995        352583             290437
# 10  2022         394328       99803        352755             302083
# 11  2021         365817       94680        351002             287912
#
#     Cash Flow from Operating Activities    Company  Revenue Growth (%)  \
# 0                                118548  Microsoft            0.000000
# 1                                 87582  Microsoft          -13.547132
# 2                                 89035  Microsoft           -6.438902
# 3                                 76740  Microsoft          -15.222676
# 4                                 14923      Tesla            0.000000
# 5                                 13256      Tesla           -0.938684
# 6                                 14724      Tesla          -15.821562
# 7                                 11497      Tesla          -33.931158
# 8                                118500      Apple            0.000000
# 9                                110543      Apple           -1.981920
# 10                               122151      Apple            2.881146
# 11                               104038      Apple           -7.230275
#
#     Net Income Growth (%)
# 0                0.000000
# 1              -17.898475
# 2                0.520999
# 3              -15.764800
# 4                0.000000
# 5              111.169088
# 6              -16.147990
# 7              -56.044919
# 8                0.000000
# 9                3.476786
# 10               2.894995
# 11              -5.133112

# %% [markdown]
# ## Calculating Year-by-Year growth rates for Total Assets, Total Liabilities and Cash flow from Operations Activities

# %%
data['Assets Growth (%)'] = data.groupby('Company')['Total Assets'].pct_change() * 100
data['Liabilities Growth (%)'] = data.groupby('Company')['Total Liabilities'].pct_change() * 100
data['Cash Flow from Operations Growth(%)'] = data.groupby('Company')['Cash Flow from Operating Activities'].pct_change() * 100

# %%
data
# Out:
#     Year  Total Revenue  Net Income  Total Assets  Total Liabilities  \
# 0   2024         245122       88136        512163             243686
# 1   2023         211915       72361        411976             205753
# 2   2022         198270       72738        364840             198298
# 3   2021         168088       61271        333779             191791
# 4   2024          97690        7091        106618              43009
# 5   2023          96773       14974        106618              43009
# 6   2022          81462       12556         82338              36440
# 7   2021          53821        5519         62131              30548
# 8   2024         391035       93736        364980             308030
# 9   2023         383285       96995        352583             290437
# 10  2022         394328       99803        352755             302083
# 11  2021         365817       94680        351002             287912
#
#     Cash Flow from Operating Activities    Company  Revenue Growth (%)  \
# 0                                118548  Microsoft            0.000000
# 1                                 87582  Microsoft          -13.547132
# 2                                 89035  Microsoft           -6.438902
# 3                                 76740  Microsoft          -15.222676
# 4                                 14923      Tesla            0.000000
# 5                                 13256      Tesla           -0.938684
# 6                                 14724      Tesla          -15.821562
# 7                                 11497      Tesla          -33.931158
# 8                                118500      Apple            0.000000
# 9                                110543      Apple           -1.981920
# 10                               122151      Apple            2.881146
# 11                               104038      Apple           -7.230275
#
#     Net Income Growth (%)  Assets Growth (%)  Liabilities Growth (%)  \
# 0                0.000000                NaN                     NaN
# 1              -17.898475         -19.561546              -15.566344
# 2                0.520999         -11.441443               -3.623276
# 3              -15.764800          -8.513595               -3.281425
# 4                0.000000                NaN                     NaN
# 5              111.169088           0.000000                0.000000
# 6              -16.147990         -22.772890              -15.273547
# 7              -56.044919         -24.541524              -16.169045
# 8                0.000000                NaN                     NaN
# 9                3.476786          -3.396624               -5.711457
# 10               2.894995           0.048783                4.009820
# 11              -5.133112          -0.496945               -4.691095
#
#     Cash Flow from Operations Growth(%)
# 0                                   NaN
# 1                            -26.121065
# 2                              1.659017
# 3                            -13.809176
# 4                                   NaN
# 5                            -11.170676
# 6                             11.074231
# 7                            -21.916599
# 8                                   NaN
# 9                             -6.714768
# 10                            10.500891
# 11                           -14.828368

# %%
data.fillna(0, inplace=True)

# %%
data
# Out:
#     Year  Total Revenue  Net Income  Total Assets  Total Liabilities  \
# 0   2024         245122       88136        512163             243686
# 1   2023         211915       72361        411976             205753
# 2   2022         198270       72738        364840             198298
# 3   2021         168088       61271        333779             191791
# 4   2024          97690        7091        106618              43009
# 5   2023          96773       14974        106618              43009
# 6   2022          81462       12556         82338              36440
# 7   2021          53821        5519         62131              30548
# 8   2024         391035       93736        364980             308030
# 9   2023         383285       96995        352583             290437
# 10  2022         394328       99803        352755             302083
# 11  2021         365817       94680        351002             287912
#
#     Cash Flow from Operating Activities    Company  Revenue Growth (%)  \
# 0                                118548  Microsoft            0.000000
# 1                                 87582  Microsoft          -13.547132
# 2                                 89035  Microsoft           -6.438902
# 3                                 76740  Microsoft          -15.222676
# 4                                 14923      Tesla            0.000000
# 5                                 13256      Tesla           -0.938684
# 6                                 14724      Tesla          -15.821562
# 7                                 11497      Tesla          -33.931158
# 8                                118500      Apple            0.000000
# 9                                110543      Apple           -1.981920
# 10                               122151      Apple            2.881146
# 11                               104038      Apple           -7.230275
#
#     Net Income Growth (%)  Assets Growth (%)  Liabilities Growth (%)  \
# 0                0.000000           0.000000                0.000000
# 1              -17.898475         -19.561546              -15.566344
# 2                0.520999         -11.441443               -3.623276
# 3              -15.764800          -8.513595               -3.281425
# 4                0.000000           0.000000                0.000000
# 5              111.169088           0.000000                0.000000
# 6              -16.147990         -22.772890              -15.273547
# 7              -56.044919         -24.541524              -16.169045
# 8                0.000000           0.000000                0.000000
# 9                3.476786          -3.396624               -5.711457
# 10               2.894995           0.048783                4.009820
# 11              -5.133112          -0.496945               -4.691095
#
#     Cash Flow from Operations Growth(%)
# 0                              0.000000
# 1                            -26.121065
# 2                              1.659017
# 3                            -13.809176
# 4                              0.000000
# 5                            -11.170676
# 6                             11.074231
# 7                            -21.916599
# 8                              0.000000
# 9                             -6.714768
# 10                            10.500891
# 11                           -14.828368

# %%
data.to_csv('final_data_report.csv')

# %%
summary = data.groupby('Company').agg({
    'Revenue Growth (%)': 'mean',
    'Net Income Growth (%)': 'mean',
    'Assets Growth (%)' : 'mean',
    'Liabilities Growth (%)' : 'mean',
    'Cash Flow from Operations Growth(%)' :'mean'    
}).reset_index()

# %%
print('Year-By-Year Average Growth Rates(%) :-')
print('             OR')
print("Overall Growth/Fall rate for Apple, Microsoft and Tesla from Fiscal Year 2021 - 2023")
summary
# Out:
# Year-By-Year Average Growth Rates(%) :-
#              OR
# Overall Growth/Fall rate for Apple, Microsoft and Tesla from Fiscal Year 2021 - 2023
#      Company  Revenue Growth (%)  Net Income Growth (%)  Assets Growth (%)  \
# 0      Apple           -1.582762               0.309667          -0.961197
# 1  Microsoft           -8.802178              -8.285569          -9.879146
# 2      Tesla          -12.672851               9.744045         -11.828604
#
#    Liabilities Growth (%)  Cash Flow from Operations Growth(%)
# 0               -1.598183                            -2.760561
# 1               -5.617761                            -9.567806
# 2               -7.860648                            -5.503261

# %%
summary.to_csv('Summary_final_report.csv')
